# %% [markdown]
# # RED CORNER VS BLUE CORNER

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt 
import seaborn as sns


x_labels = ['rf','bf','winner','rwins','bwins','rloses','bloses','rslpm','bslpm','rstrac','bstrac','rsapm','bsapm','rstrd','bstrd','rtdav',
           'btdav', 'rtdac','btdac','rtdd','btdd','rsubav','bsubav']

stat_indexes = [4,5,13,14,15,16,17,18,19,20]

# %%
fighter_stats = {}

with open('fighters.csv', mode='r') as inp:
    reader =csv.reader(inp)
    fighter_stats = {rows[0]:rows[0:] for rows in reader}


fighter_df = pd.read_csv('fighters.csv')
fights_df = pd.read_csv('fights.csv')


X = pd.DataFrame(columns=x_labels)

for row in fights_df.itertuples():
    ##still need to set winner array
    temp_ar = []
    rf = row[1]
    bf = row[2]
    
    rwin = row[3]
    bwin = row[4]

    if rwin != bwin:
        temp_ar.append(rf)
        temp_ar.append(bf)
        
        winner = 1 if rwin == 1 else 0
        temp_ar.append(winner)
        
        rf_stats = fighter_stats[rf]
        bf_stats = fighter_stats[bf]

        for index in stat_indexes:
            rstat = rf_stats[index]
            bstat = bf_stats[index]
            temp_ar.append(rstat)
            temp_ar.append(bstat)

        X = pd.concat([pd.DataFrame([temp_ar], columns=x_labels), X], ignore_index=True)

# %%
for index in x_labels[3:]:
    #should title and stuff
    X[index].astype(float).plot.box()
    plt.show()
# Out:
# rwins
# bwins
# rloses
# bloses
# rslpm
# bslpm
# rstrac
# bstrac
# rsapm
# bsapm
# rstrd
# bstrd
# rtdav
# btdav
# rtdac
# btdac
# rtdd
# btdd
# rsubav
# bsubav

# %%
X.groupby('winner').size().rename({0:"Blue Wins",1:"Red Wins"}).plot.bar(rot=0,color=["blue","red"])
# Out:
# <AxesSubplot:xlabel='winner'>

# %% [markdown]
# NOTE: The red corner has won 2x more fights than the blue corner since the start of the UFC. This is something to keep an eye on while creating the model to predict fights. I don't want the model to be more favored to predict the red corner just because the data has more examples of the Red corner winning. After creating more graphs for the rest of the data, I intend to randomize the corners to get a more even split of corner wins. Is this a reccomended strategy in ML? I should do some research.

# %%
X.loc[:,"rwins":].astype(float).describe()
# Out:
#              rwins        bwins       rloses       bloses        rslpm  \
# count  6456.000000  6456.000000  6456.000000  6456.000000  6456.000000
# mean     19.157373    17.103934     7.815675     7.294300     3.299607
# std       9.757939     9.521025     4.620378     4.513288     1.308372
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      13.000000    11.000000     5.000000     4.000000     2.470000
# 50%      18.000000    16.000000     7.000000     6.000000     3.210000
# 75%      24.000000    21.000000    10.000000     9.000000     4.020000
# max     253.000000   253.000000    53.000000    53.000000    10.530000
#
#              bslpm       rstrac       bstrac        rsapm        bsapm  \
# count  6456.000000  6456.000000  6456.000000  6456.000000  6456.000000
# mean      3.135184     0.435451     0.422062     3.162049     3.335620
# std       1.427229     0.095444     0.114234     1.197013     1.499831
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.230000     0.390000     0.380000     2.420000     2.500000
# 50%       3.115000     0.440000     0.430000     3.030000     3.130000
# 75%       3.960000     0.490000     0.490000     3.830000     4.030000
# max      12.070000     0.830000     1.000000    15.480000    22.500000
#
#              rstrd        bstrd        rtdav        btdav        rtdac  \
# count  6456.000000  6456.000000  6456.000000  6456.000000  6456.000000
# mean      0.547344     0.524133     1.609360     1.458243     0.390361
# std       0.102611     0.122839     1.279041     1.310688     0.192351
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.510000     0.490000     0.607500     0.480000     0.290000
# 50%       0.560000     0.540000     1.360000     1.170000     0.390000
# 75%       0.610000     0.590000     2.360000     2.120000     0.500000
# max       0.840000     1.000000    11.110000    13.950000     1.000000
#
#              btdac         rtdd         btdd       rsubav       bsubav
# count  6456.000000  6456.000000  6456.000000  6456.000000  6456.000000
# mean      0.360545     0.598367     0.557677     0.661462     0.629879
# std       0.221601     0.209481     0.247200     0.748364     0.843557
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.240000     0.500000     0.440000     0.100000     0.000000
# 50%       0.360000     0.620000     0.600000     0.500000     0.400000
# 75%       0.500000     0.740000     0.720000     0.900000     0.900000
# max       1.000000     1.000000     1.000000    15.500000    16.400000

# %%
X.loc[:,"winner":].astype(float).groupby('winner').mean().rename({0:"Blue Wins",1:"Red Wins"}).plot(kind='bar', subplots=True,figsize=(15,75),rot=0)
# Out:
# array([<AxesSubplot:title={'center':'rwins'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bwins'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rloses'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bloses'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rslpm'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bslpm'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rstrac'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bstrac'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rsapm'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bsapm'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rstrd'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bstrd'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rtdav'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'btdav'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rtdac'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'btdac'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rtdd'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'btdd'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'rsubav'}, xlabel='winner'>,
#        <AxesSubplot:title={'center':'bsubav'}, xlabel='winner'>],
#       dtype=object)

# %%
pd.options.display.max_columns = 999
X.loc[:,"winner":].astype(float).groupby('winner').describe(include="all")
# Out:
#          rwins                                                        bwins  \
#          count       mean        std  min   25%   50%    75%    max   count
# winner
# 0.0     2144.0  17.446828   8.363028  0.0  11.0  16.0  22.00   60.0  2144.0
# 1.0     4312.0  20.007885  10.277452  1.0  14.0  19.0  24.25  253.0  4312.0
#
#                                                             rloses            \
#              mean        std  min   25%   50%   75%    max   count      mean
# winner
# 0.0     17.761194   7.521868  1.0  13.0  17.0  22.0   60.0  2144.0  7.716418
# 1.0     16.777134  10.357905  0.0  10.0  15.0  21.0  253.0  4312.0  7.865028
#
#                                              bloses                           \
#              std  min  25%  50%   75%   max   count      mean       std  min
# winner
# 0.0     4.231164  0.0  5.0  7.0  10.0  23.0  2144.0  6.373134  3.976453  0.0
# 1.0     4.801884  0.0  4.0  7.0  11.0  53.0  4312.0  7.752319  4.691293  0.0
#
#                                rslpm                                         \
#         25%  50%   75%   max   count      mean       std  min     25%   50%
# winner
# 0.0     3.0  6.0   8.0  22.0  2144.0  3.326558  1.195467  0.0  2.5300  3.23
# 1.0     4.0  7.0  10.0  53.0  4312.0  3.286206  1.360964  0.0  2.4475  3.20
#
#                       bslpm                                                    \
#          75%    max   count      mean       std  min   25%   50%   75%    max
# winner
# 0.0     3.96  10.53  2144.0  3.687589  1.285102  0.0  2.87  3.57  4.36  12.07
# 1.0     4.04  10.53  4312.0  2.860519  1.414873  0.0  1.95  2.84  3.72   8.76
#
#         rstrac                                                   bstrac  \
#          count      mean       std  min   25%   50%   75%   max   count
# winner
# 0.0     2144.0  0.433144  0.078883  0.0  0.39  0.43  0.48  0.75  2144.0
# 1.0     4312.0  0.436598  0.102678  0.0  0.40  0.44  0.50  0.83  4312.0
#
#                                                           rsapm            \
#             mean       std  min   25%   50%   75%   max   count      mean
# winner
# 0.0     0.450340  0.072900  0.0  0.41  0.45  0.49  0.79  2144.0  3.488358
# 1.0     0.408001  0.127679  0.0  0.36  0.42  0.48  1.00  4312.0  2.999803
#
#                                                   bsapm                      \
#              std  min  25%   50%     75%    max   count      mean       std
# winner
# 0.0     1.193388  0.4  2.7  3.31  4.0700  15.48  2144.0  3.356674  1.163085
# 1.0     1.165416  0.0  2.3  2.92  3.6825  10.27  4312.0  3.325151  1.641782
#
#                                         rstrd                                  \
#          min   25%   50%   75%    max   count      mean       std   min   25%
# winner
# 0.0     0.13  2.58  3.21  3.94   9.84  2144.0  0.547127  0.073906  0.19  0.51
# 1.0     0.00  2.44  3.10  4.06  22.50  4312.0  0.547451  0.114238  0.00  0.52
#
#                            bstrd                                             \
#          50%   75%   max   count      mean       std  min   25%   50%   75%
# winner
# 0.0     0.55  0.60  0.81  2144.0  0.555084  0.069635  0.2  0.51  0.56  0.60
# 1.0     0.57  0.61  0.84  4312.0  0.508743  0.139535  0.0  0.47  0.54  0.59
#
#                rtdav                                                    \
#          max   count      mean       std  min   25%   50%   75%    max
# winner
# 0.0     0.92  2144.0  1.482034  1.197535  0.0  0.56  1.24  2.12   7.50
# 1.0     1.00  4312.0  1.672669  1.313238  0.0  0.65  1.42  2.46  11.11
#
#          btdav                                                     rtdac  \
#          count      mean       std  min   25%   50%   75%    max   count
# winner
# 0.0     2144.0  1.614305  1.328653  0.0  0.61  1.35  2.35   9.15  2144.0
# 1.0     4312.0  1.380647  1.294834  0.0  0.40  1.10  2.04  13.95  4312.0
#
#                                                            btdac            \
#             mean       std  min   25%   50%     75%  max   count      mean
# winner
# 0.0     0.367593  0.193572  0.0  0.26  0.37  0.4725  1.0  2144.0  0.385079
# 1.0     0.401681  0.190755  0.0  0.30  0.40  0.5000  1.0  4312.0  0.348346
#
#                                                 rtdd                           \
#              std  min   25%   50%   75%  max   count      mean       std  min
# winner
# 0.0     0.187976  0.0  0.28  0.38  0.49  1.0  2144.0  0.591782  0.206737  0.0
# 1.0     0.235618  0.0  0.20  0.35  0.50  1.0  4312.0  0.601642  0.210779  0.0
#
#                                 btdd                                       \
#         25%   50%   75%  max   count      mean       std  min   25%   50%
# winner
# 0.0     0.5  0.62  0.73  1.0  2144.0  0.635951  0.194813  0.0  0.54  0.65
# 1.0     0.5  0.63  0.74  1.0  4312.0  0.518757  0.260904  0.0  0.37  0.57
#
#                    rsubav                                                \
#          75%  max   count      mean       std  min  25%  50%  75%   max
# winner
# 0.0     0.76  1.0  2144.0  0.596642  0.723402  0.0  0.1  0.4  0.8  12.1
# 1.0     0.70  1.0  4312.0  0.693692  0.758493  0.0  0.2  0.5  1.0  15.5
#
#         bsubav
#          count      mean       std  min  25%  50%  75%   max
# winner
# 0.0     2144.0  0.597948  0.720272  0.0  0.1  0.4  0.8  12.1
# 1.0     4312.0  0.645756  0.898240  0.0  0.0  0.4  0.9  16.4

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(X.loc[:,"rwins":].astype(float).corr(method='pearson'))
# Out:
# <AxesSubplot:>

# %%
X.loc[:,"winner":].astype(float).corr()
# Out:
#           winner     rwins     bwins    rloses    bloses     rslpm     bslpm  \
# winner  1.000000  0.123618 -0.048681  0.015149  0.143930 -0.014526 -0.272942
# rwins   0.123618  1.000000  0.223002  0.646871  0.216276 -0.070374 -0.081393
# bwins  -0.048681  0.223002  1.000000  0.179211  0.676053 -0.034268  0.025422
# rloses  0.015149  0.646871  0.179211  1.000000  0.225562 -0.184920 -0.130786
# bloses  0.143930  0.216276  0.676053  0.225562  1.000000 -0.099877 -0.134112
# rslpm  -0.014526 -0.070374 -0.034268 -0.184920 -0.099877  1.000000  0.354155
# bslpm  -0.272942 -0.081393  0.025422 -0.130786 -0.134112  0.354155  1.000000
# rstrac  0.017046  0.026337  0.091313 -0.086316  0.011312  0.418089  0.184392
# bstrac -0.174572 -0.028294  0.127949 -0.077185 -0.019071  0.223024  0.472204
# rsapm  -0.192237 -0.166426 -0.065976 -0.022441 -0.098351  0.531901  0.351970
# bsapm  -0.009900 -0.108644 -0.092796 -0.125175 -0.054642  0.373483  0.479353
# rstrd   0.001489  0.103188  0.177745  0.007234  0.098337  0.349821  0.186129
# bstrd  -0.177685  0.038727  0.202016 -0.017058  0.064473  0.227577  0.412796
# rtdav   0.070201  0.023574  0.073450 -0.120503  0.039952 -0.141629 -0.031383
# btdav  -0.083966  0.038726  0.095972  0.015322 -0.049698 -0.012891 -0.072841
# rtdac   0.083470  0.129823  0.115364  0.071824  0.101298  0.091078 -0.000257
# btdac  -0.078074  0.049482  0.156177  0.018453  0.092038  0.034999  0.166513
# rtdd    0.022170  0.040189  0.107691 -0.051188  0.014721  0.384569  0.164719
# btdd   -0.223296  0.013583  0.137676 -0.064179 -0.005065  0.185437  0.441867
# rsubav  0.061081  0.090632  0.058849  0.073695  0.084309 -0.197929 -0.102743
# bsubav  0.026694  0.062073  0.118886  0.100282  0.091881 -0.062561 -0.170226
#
#           rstrac    bstrac     rsapm     bsapm     rstrd     bstrd     rtdav  \
# winner  0.017046 -0.174572 -0.192237 -0.009900  0.001489 -0.177685  0.070201
# rwins   0.026337 -0.028294 -0.166426 -0.108644  0.103188  0.038727  0.023574
# bwins   0.091313  0.127949 -0.065976 -0.092796  0.177745  0.202016  0.073450
# rloses -0.086316 -0.077185 -0.022441 -0.125175  0.007234 -0.017058 -0.120503
# bloses  0.011312 -0.019071 -0.098351 -0.054642  0.098337  0.064473  0.039952
# rslpm   0.418089  0.223024  0.531901  0.373483  0.349821  0.227577 -0.141629
# bslpm   0.184392  0.472204  0.351970  0.479353  0.186129  0.412796 -0.031383
# rstrac  1.000000  0.310214  0.124265  0.187016  0.335586  0.179525  0.223670
# bstrac  0.310214  1.000000  0.225451  0.150725  0.232769  0.423007  0.088224
# rsapm   0.124265  0.225451  1.000000  0.290760  0.056080  0.194648 -0.268653
# bsapm   0.187016  0.150725  0.290760  1.000000  0.190473  0.099125 -0.052384
# rstrd   0.335586  0.232769  0.056080  0.190473  1.000000  0.474253  0.141118
# bstrd   0.179525  0.423007  0.194648  0.099125  0.474253  1.000000  0.084666
# rtdav   0.223670  0.088224 -0.268653 -0.052384  0.141118  0.084666  1.000000
# btdav   0.071046  0.239329 -0.022924 -0.201080  0.111360  0.182895  0.041547
# rtdac   0.303653  0.075418 -0.115185  0.002298  0.262279  0.105145  0.371798
# btdac   0.095588  0.304143  0.032820 -0.090257  0.146880  0.307006  0.044356
# rtdd    0.277716  0.177995  0.173085  0.139753  0.441737  0.244628  0.055485
# btdd    0.165673  0.337091  0.145292  0.118209  0.223934  0.459261  0.016853
# rsubav  0.108481  0.012016 -0.099546 -0.059901 -0.021023  0.014534  0.222297
# bsubav  0.030199  0.107378 -0.054420 -0.106894  0.067335  0.008067  0.052244
#
#            btdav     rtdac     btdac      rtdd      btdd    rsubav    bsubav
# winner -0.083966  0.083470 -0.078074  0.022170 -0.223296  0.061081  0.026694
# rwins   0.038726  0.129823  0.049482  0.040189  0.013583  0.090632  0.062073
# bwins   0.095972  0.115364  0.156177  0.107691  0.137676  0.058849  0.118886
# rloses  0.015322  0.071824  0.018453 -0.051188 -0.064179  0.073695  0.100282
# bloses -0.049698  0.101298  0.092038  0.014721 -0.005065  0.084309  0.091881
# rslpm  -0.012891  0.091078  0.034999  0.384569  0.185437 -0.197929 -0.062561
# bslpm  -0.072841 -0.000257  0.166513  0.164719  0.441867 -0.102743 -0.170226
# rstrac  0.071046  0.303653  0.095588  0.277716  0.165673  0.108481  0.030199
# bstrac  0.239329  0.075418  0.304143  0.177995  0.337091  0.012016  0.107378
# rsapm  -0.022924 -0.115185  0.032820  0.173085  0.145292 -0.099546 -0.054420
# bsapm  -0.201080  0.002298 -0.090257  0.139753  0.118209 -0.059901 -0.106894
# rstrd   0.111360  0.262279  0.146880  0.441737  0.223934 -0.021023  0.067335
# bstrd   0.182895  0.105145  0.307006  0.244628  0.459261  0.014534  0.008067
# rtdav   0.041547  0.371798  0.044356  0.055485  0.016853  0.222297  0.052244
# btdav   1.000000  0.034725  0.431407  0.005554  0.092381  0.084093  0.177200
# rtdac   0.034725  1.000000  0.042962  0.226126 -0.024654  0.087860  0.046118
# btdac   0.431407  0.042962  1.000000 -0.012609  0.246672  0.056289  0.067231
# rtdd    0.005554  0.226126 -0.012609  1.000000  0.145545 -0.244279 -0.000913
# btdd    0.092381 -0.024654  0.246672  0.145545  1.000000 -0.035007 -0.136734
# rsubav  0.084093  0.087860  0.056289 -0.244279 -0.035007  1.000000  0.102264
# bsubav  0.177200  0.046118  0.067231 -0.000913 -0.136734  0.102264  1.000000
